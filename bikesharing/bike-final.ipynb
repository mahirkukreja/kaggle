# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('casual.csv')
train1=pd.read_csv('registered.csv')

# %%
train['count']=train['casual']+train1['registered']

# %%
train['count']=['0' if x<0 else x for x in train['count']]

# %%
del train['casual']

# %%
train
# Out:
#                  datetime    count
# 0     2011-01-20 00:00:00  11.7729
# 1     2011-01-20 01:00:00        0
# 2     2011-01-20 02:00:00        0
# 3     2011-01-20 03:00:00        0
# 4     2011-01-20 04:00:00        0
# 5     2011-01-20 05:00:00  14.7459
# 6     2011-01-20 06:00:00  58.7918
# 7     2011-01-20 07:00:00  135.809
# 8     2011-01-20 08:00:00  288.696
# 9     2011-01-20 09:00:00  127.954
# 10    2011-01-20 10:00:00  41.1918
# 11    2011-01-20 11:00:00  29.3997
# 12    2011-01-20 12:00:00  73.2126
# 13    2011-01-20 13:00:00  52.1346
# 14    2011-01-20 14:00:00  41.6412
# 15    2011-01-20 15:00:00   56.499
# 16    2011-01-20 16:00:00  86.2542
# 17    2011-01-20 17:00:00   226.77
# 18    2011-01-20 18:00:00  189.401
# 19    2011-01-20 19:00:00  106.908
# 20    2011-01-20 20:00:00  82.6007
# 21    2011-01-20 21:00:00  68.2349
# 22    2011-01-20 22:00:00  39.5956
# 23    2011-01-20 23:00:00   22.037
# 24    2011-01-21 00:00:00  11.8513
# 25    2011-01-21 01:00:00  2.34893
# ...

# %%
train.to_csv('count.csv',index=False)
